# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlencode
import csv

# %% [markdown]
# ### Define a list of URL's that will be scraped.

# %%
list_of_urls = ['https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=3',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=4',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=5',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=6',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=7',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=8',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=9',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=10',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=11',
'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TV2P1N8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=12']

# %% [markdown]
# ### Retrieve each of the url's HTML data and convert the data into a beautiful soup object.
# ### Find, extract and store reviewer names and review text into a list.

# %%
names = []
reviews = []
data_string = ""

for url in list_of_urls: 
    params = {'api_key': "d0c22206da326cf5c4478fe143288b0f", 'url': url}
    response = requests.get('http://api.scraperapi.com/',   params=urlencode(params))
    soup = BeautifulSoup(response.text, 'html.parser')

    for item in soup.find_all("span", class_="a-profile-name"):
      data_string = data_string + item.get_text()
      names.append(data_string)
      data_string = ""  
    
    for item in soup.find_all("span", {"data-hook": "review-body"}):
      data_string = data_string + item.get_text()
      reviews.append(data_string)
      data_string = ""

# %% [markdown]
# ### Create the dictionary.

# %%
reviews_dict = {'Reviewer Name': names, 'Reviews': reviews}
reviews_dict
# Out:
# {'Reviewer Name': ['Shokeenism Reviews',
#   'Amazon Customer',
#   'Shokeenism Reviews',
#   'RK',
#   'Brijesh Mehta',
#   'Rifuu',
#   'Promit',
#   'Anil Patil',
#   'Zaira',
#   'sandeep reddy',
#   'sandeep reddy',
#   'kamalakara r.',
#   'Amazon Customer',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Anurag',
#   'Piyush Pravasi',
#   'AKIL ANSAR MULLICK',
#   'Kumar Rahul',
#   'Ajay',
#   'Akash',
#   'Jagat',
#   'Vitthal Bondar',
#   'ATANU',
#   'Jitendra Gurjar',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Rekha',
#   'Shweta',
#   'Nice neck bend ',
#   'Kunal kumar',
#   'Shaik Rahim',
#   'Soumyadip Mandal',
#   'Eby',
#   'Ishrath fatima',
#   'K Dileep Kumar',
#   'Puspa Chowdhury',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'rajathan ...',
#   'Naveena',
#   'Ramlakhan Kashyap',
#   'voice calling not good ',
#   'Amazon Customer',
#   'Anubhav Tiwari',
#   'Rishi',
#   'Mohnish Jain',
#   'saloni singh',
#   'Amazon Customer',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Sanker Gopinath',
#   'Pooja Ramchandra Pisal',
#   'REDDYVENKATANARAYANA',
#   'Vishwajeet Kumar',
#   'Amazon Customer',
#   'Boat rockerz 255 Pro plus ',
#   'Product User',
#   'Abhishek limba',
#   'Jayesh kihla',
#   'Battery backup too good.. ',
#   'Battery backup too good.. ',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'vikas kadam',
#   'ANAND INGLE',
#   'Jayalakshmi V Janardhan',
#   'Jayalakshmi V Janardhan',
#   'srithar',
#   'Bharathidasan',
#   'srinivas.M',
#   'Ganesh Prasad bind',
#   'Durga jangid',
#   'Durga jangid',
#   'Rathesh',
#   'Selvasutha',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Vankar kuldip',
#   'ravindra',
#   'Ramanathan',
#   'Pankaj kumar ',
#   'Am',
#   'Ayush jeph',
#   'Ayush jeph',
#   'Anil',
#   'Ramesh Salokhe',
#   'G. Santoshi',
#   'rohan',
#   'rohan',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Nandita Paul',
#   'Anshul',
#   'Placeholder',
#   'Karthick S',
#   'Kaushik Baul',
#   'sameer d.',
#   'sameer d.',
#   ' Mahindra ',
#   'Kishan Kumar',
#   'Manisha Kumari',
#   'Sargam jain',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Bittu tung',
#   'Bittu tung',
#   'Amazon Customer',
#   'Dr Mukesh Siddhapara',
#   'ANIRUDDHA MONDAL',
#   'ANIRUDDHA MONDAL',
#   'Jk',
#   'Ashutosh tripathi',
#   'Ashutosh tripathi',
#   'Vikas',
#   'Tiger1246',
#   'Stopped working in just 12 days. Never buy this product ',
#   'Saurav Rawat',
#   'Shokeenism Reviews',
#   'Amazon Customer',
#   'Shokeenism Reviews',
#   'Amazon Customer'],
#  'Reviews': ["\nI brought this boat wireless headphones multiple times. The headphones are fantastic and worth the money. Here are some of the pros and cons of these headphones:Pros:The sound quality is amazingLong battery backupcompatible with all Bluetooth devices.Can connect two devices simultaneously.Multidevice connecting featureNoise cancellation is amazing.Fast charging takes almost half an hour to charge the battery fully.Last but not least water resistant.Cons:Can cause ear pain in long-time continuous use.Come out from the ear while running or exercising.Sometimes disconnects automatically and again connects automatically.So those were the pros and cons of these boats' Bluetooth earphones. I have been using these earphones for a long time. That was my review, and I hope you will find it helpful. Don't forget to follow for other product reviews.\n",
#   '\nOverall an excellent product at this price. What i love about it is the dual paring which stays connected to 2 device at the same time. I earlier used apple airpods which automatically switches to device as per need. After using this neckband i am really not missing airpods as this also switches automatically. One star less as the ear buds are little uncomfortable on prolonged use.\n',
#   '\nfull marks to sound quality.Dual connectivity is plusMagnets are not that great. it wont pause / play with magnates.too bulky and heavy compare to peers\n',
#   '\nGOOD PRODUCT BUT EVERYONE CANT BEAR TO USE IN WARM WEATHER N DIPPER AT NIGHT DISTRBING DURING COL\n',
#   "\nI'm writing this review after using the product for 10 mnths,Pros:The bass of the product is really impressive for this budgetYou'll get auto magnetic touch on/off switch.I've used this product during rains and it's still workingThe sound quality is impressive not good as Sony though!!ConsThe speaker of the band while calling gives a  little bit of issue.\n",
#   '\noverall quality  is nice but bass quality is not much better..price should be less\n',
#   '\nNeckband is of good quality. Gives a playback of more than 3 days. Sound quality is better too. You should really go for this one.\n',
#   '\nVery good headset at this price range.Connects very quickly and supports dual connection.One problem is that it prompts for all nearby devices to get connected\n',
#   '\nJust okokok  sound quality is not good\n',
#   '\nGood Product value for money 👌\n',
#   "\nIt's right ear heavier because of button encloser\n",
#   '\nSatisfied with the product, Recommended product\n',
#   '\nGood headhone in this range price\n',
#   '\nWorth buying according to price\n',
#   '\nGood\n',
#   "\nThe battery lasts for days (I don't use it continuously) after just an hour of charging. It's not too tight on the ears but does good job of noise cancellation\n",
#   "\nIt's sound is so soothing..👍Bass quality is not so good..\n",
#   '\nNice\n',
#   '\nGreat build quality, acceptable sound quality. No issues with connectivity, tried both iOS & Android.\n',
#   '\nNice products good quality of audio comfortable in ear for long hours\n',
#   '\nAayi to aachi thi baad mei dikkat huyi bt ab thik hai\n',
#   "\nIt's always good experience shopping with Amazon.I received boat rockerzs on time.But it's  causing problem while wearing.Right Ear piece of headphones are falling again again which causes Distrubunce while studying.That's why I returning this product.And on other hand left one is good.I'm  100% sure that Amazon will definitely solve my issue.\n",
#   "\nIt's base is awesome and battery back up is so good\n",
#   '\nProduct is good .sound quality is good\n',
#   '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\xa0A Product with good sound quality and nice hand features. Definitely buy it ....I am really impressed with sound...And that volume increasing and decreasing feature is so good and working well....The product is also so smooth to touch and fitting is very good..Thanks Amazon..❤️\n',
#   '\nNow some odour seen in the charging point, and sometimes when I not used more than 2-3 days, one problem occurs it automatically disconnect blootooth connection. It is the big problem, overall sound quality is very very good, overall good product.\n',
#   '\nIt is a good product.It has a good battery backup.Very comfortable to use . Light weight.\n',
#   '\nGood product 👍👍\n',
#   '\nEar phone buds not fix ear properly\n',
#   '\nGood quality\n',
#   '\nGood product\n',
#   '\nSuper\n',
#   '\nAchha hai bahut badhiya Ise kharide bindass hoke\n',
#   '\nvoice calling not good\n',
#   '\nBattery last somewhere between 2-4 days on regular usage\n',
#   '\n* fast charging* type c data cable* approx. 40 hours audio and video playback time when fully charged.* easy to carry\n',
#   "\nThe sound quality is good butThe bass is all it have so if you are a bass lover then it is for youBut if you are buying it for listening during the run or any physical activity then it might be problematic because it's mic part makes right bud pop out of the ear.\n",
#   '\nSound ,battery life, build quality very thing is cool. Nice product.\n',
#   '\nsound quality good. the extra goodies they gave me made my daym\n',
#   '\nIts slightly bigger than you expect, but performance wise its good. Bang for the buck. Can reduce lot of noise and produces immersive experience. Good to have foldable feature.\n',
#   '\nLiked it.\n',
#   '\nOk ok\n',
#   '\nసూపర్\n',
#   '\nGoog\n',
#   "\nI bought this in March 2023. It has already conked off. Agreed, there is a warranty, but to claim it, I have to pay 1000 rupees to an uber guy and apply a day leave from work. Is it practical? Not at all. I might as well buy an unbranded headphone for 300 that lasts 3 months. Useless product. Don't even buy it.Edit: I wanted to add more to the above feedback. I was upset with this product and went to the twitter page of Boat and made a complaint. I got a response asking me to raise a request on their site. After doing so, they arranged a pick up of the product from my home, got it checked, confirmed that the product is defective and sent me a replacement, which I received today. So, that's my feedback. Their warranty claim process is good. So yes. I may consider buying another Boat in future because of this.\n",
#   '\nMujhe to bhot acha laga boat rockerz 255 pro plus headphones\n',
#   '\nthe product is great, the reason i gave a 4star is for its connectivity issues. it connects any of the random Bluetooth device or any strange device in the crowded areas. Anybody can connect device to this neckband if its already connected to your phone.\n',
#   "\nThe wire length and design itself is inconvenient. I cannot walk around freely without those two loops of wire constantly touching/hitting my face.The controller box could be moved to the right end of the neckband. That would be nice I guess but hey I'm just talking a customer experience so idk what you guys had in mind... Though I have seen other neckband earphones with that design and they are lighter which brings my next problem with the earphones— it's too heavy on my ears and overall.On the good point, In the sound quality, never have BOAT disappointed me so yeah been loving it so far. Battery back is great. Charging is fast.\n",
#   '\nVery like is\n',
#   '',
#   '\nboAt Rockerz 255 Pro+ Bluetooth in Ear Earphones is very good product from boat charging super fast sound equality is very good value for money.\n',
#   '\nLow sound..\n',
#   "\nI'm using this product for 2 days and I have had a great experience with it.With the ENx technology, the Rockerz 255 Neo ensures crystal clear voice calls by effectively canceling out environmental noise.The magnetic sensors inside the buds, automatically detect if they are in use or not. To power them off, simply unite the buds, and to power them on, separate them. This intuitive feature adds convenience to your daily usage.The ASAP Charge technology allows the Rockerz 255 Neo to deliver an impressive 10 hours of playtime with just a 10-minute charge. and With a full charge, these earbuds offer an extended playback time of up to 25 hours.The Rockerz 255 Neo features a low latency BEAST Mode, perfect for gaming enthusiasts. This mode minimizes audio delay.Connectivity is a breeze with the ability to connect the Rockerz 255 Neo to two devices simultaneously using Bluetooth v5.2. Whether you want to switch between your phone and laptop or share audio with a friend.With an IPX6 rating, the Rockerz 255 Neo is designed to withstand sweat and water splashes.Featuring a 12 mm large dynamic driver, these earbuds deliver a powerful bass that transports you to another world of music.The Rockerz 255 Neo provides multiple controls for easy management of calls and music. The multifunction button allows you to answer, hang up, or reject calls, play or pause music, and even wake up your smart assistant. Additionally, dedicated buttons for volume and track control add convenience to your usage.\n",
#   '\nNice very nice 👌\n',
#   '\nLong time use\n',
#   '\nNice product\n',
#   '\nThanks\n',
#   '\nNice\n',
#   "\nEverything is good about this earphone except one thing. It doesn't fit properly in your ear. Apart from this battery life, sound quality, charging speed is nice\n",
#   '\nPreviously i am using the same model same neckband.. I missed my old. Now I buy new one but compare to my old neckband this new one not good that much.. But ok..\n',
#   "\nBuilt quality I'd good.\n",
#   '\nGood\n',
#   '\nGood sounds quality and battery backup is good worth....purchase i have done.\n',
#   "\nNice product but now facing some connectivity issue but it's really good\n",
#   '\nNyz product\n',
#   '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\xa0Fasted dilvery, best earphone, sounds quality is bestBest selling price\n',
#   '\nPerfect product\n',
#   '\nVery good\n',
#   "\nGood quality but it's frequently give notification to connect the older version of this is good then the update\n",
#   '\nSound and battery back up great. Very good product.\n',
#   '\nthe product is good but not best\n',
#   '\nProduct is good with great sound and quality is also good but it feels heavy in ear because of metal and if you are like bass and wants a long lasting battery so right it is value for money for you\n',
#   "\nI don't like this product\n",
#   '\nTan colour becomes dirty soon. Audio quality is good.\n',
#   '\nI have been using this for more than 7 months. Sound qualyis awesome. And the best part of it is the battery life. That is tremendous.But while making a call it creates an issue... counterpart cant hear my voice properly and that is not clear. I have verified this with multiple devices as well. So mic is having issue of course. Also the butt gets removed from its place quickly..As a result I have already lost one.However, if you are looking for to listening songs or watching movies only, this is the best for you.\n',
#   '\nSound quality is best\n',
#   '\nVoice is clear  bass is also good\n',
#   '\nBoat earphones is too good n sound is superb u carry everytime i use this product i relieved because of sound n quality i like it ❤️ its a long lasting battery 🔋 i relaxed one time charged n use it\n',
#   '\nNice quality\n',
#   '\nVery nice must buy\n',
#   '\nAll good  boss sound  calll super\n',
#   '\nGood quality.. 👍\n',
#   '\nThe product was good in this price.\n',
#   '\nOverall good in all aspects. Thanks Amazon for on time delivery.\n',
#   '\nGo for it\n',
#   '\nBahut sundar he aur acha bhi he\n',
#   '\nNice sound and durable.\n',
#   '\nDelicate\n',
#   '\nWorking really well for me.\n',
#   "\nThis earphone is good and perfect if you are searching ofr durable and better sound quality but i would not recommend you if you are finding any boat products as comfortable and about boat 255 pro plus  it always slips off if you have small  and oily ears even with ear hooks it won't settles in my ears and the neckband wire length is too small it will be frustrating if you have long neck or long height person to carry those neckband batteries with your ears\n"]}

# %% [markdown]
# ### Print the lengths of each list.

# %%
 print(len(names), len(reviews))
# Out:
# 122 90

# %% [markdown]
# ### Create a pandas DataFrame with the review texts

# %%
df = pd.DataFrame.from_dict(reviews_dict, orient='index')
df.head()
# Out:
#                                                              0    \
# Reviewer Name                                 Shokeenism Reviews
# Reviews        \nI brought this boat wireless headphones mult...
#
#                                                              1    \
# Reviewer Name                                    Amazon Customer
# Reviews        \nOverall an excellent product at this price. ...
#
#                                                              2    \
# Reviewer Name                                 Shokeenism Reviews
# Reviews        \nfull marks to sound quality.Dual connectivit...
#
#                                                              3    \
# Reviewer Name                                                 RK
# Reviews        \nGOOD PRODUCT BUT EVERYONE CANT BEAR TO USE I...
#
#                                                              4    \
# Reviewer Name                                      Brijesh Mehta
# Reviews        \nI'm writing this review after using the prod...
#
#                                                              5    \
# Reviewer Name                                              Rifuu
# Reviews        \noverall quality  is nice but bass quality is...
#
#                                                              6    \
# Reviewer Name                                             Promit
# Reviews        \nNeckband is of good quality. Gives a playbac...
#
#                                                              7    \
# Reviewer Name                                         Anil Patil
# Reviews        \nVery good headset at this price range.Connec...
#
#                                                       8    \
# Reviewer Name                                       Zaira
# Reviews        \nJust okokok  sound quality is not good\n
#
#                                               9    ...                112  \
# Reviewer Name                       sandeep reddy  ...  Ashutosh tripathi
# Reviews        \nGood Product value for money 👌\n  ...               None
#
#                              113    114        115  \
# Reviewer Name  Ashutosh tripathi  Vikas  Tiger1246
# Reviews                     None   None       None
#
#                                                              116  \
# Reviewer Name  Stopped working in just 12 days. Never buy thi...
# Reviews                                                     None
#
#                         117                 118              119  \
# Reviewer Name  Saurav Rawat  Shokeenism Reviews  Amazon Customer
# Reviews                None                None             None
#
#                               120              121
# Reviewer Name  Shokeenism Reviews  Amazon Customer
# Reviews                      None             None
#
# [2 rows x 122 columns]

# %% [markdown]
# ### **Delete all the columns that have missing values.**

# %%
df.dropna(axis=1, inplace=True)
df.head()
# Out:
#                                                               0   \
# Reviewer Name                                 Shokeenism Reviews
# Reviews        \nI brought this boat wireless headphones mult...
#
#                                                               1   \
# Reviewer Name                                    Amazon Customer
# Reviews        \nOverall an excellent product at this price. ...
#
#                                                               2   \
# Reviewer Name                                 Shokeenism Reviews
# Reviews        \nfull marks to sound quality.Dual connectivit...
#
#                                                               3   \
# Reviewer Name                                                 RK
# Reviews        \nGOOD PRODUCT BUT EVERYONE CANT BEAR TO USE I...
#
#                                                               4   \
# Reviewer Name                                      Brijesh Mehta
# Reviews        \nI'm writing this review after using the prod...
#
#                                                               5   \
# Reviewer Name                                              Rifuu
# Reviews        \noverall quality  is nice but bass quality is...
#
#                                                               6   \
# Reviewer Name                                             Promit
# Reviews        \nNeckband is of good quality. Gives a playbac...
#
#                                                               7   \
# Reviewer Name                                         Anil Patil
# Reviews        \nVery good headset at this price range.Connec...
#
#                                                        8   \
# Reviewer Name                                       Zaira
# Reviews        \nJust okokok  sound quality is not good\n
#
#                                                9   ...  \
# Reviewer Name                       sandeep reddy  ...
# Reviews        \nGood Product value for money 👌\n  ...
#
#                                                   80                    81  \
# Reviewer Name                             Ramanathan         Pankaj kumar
# Reviews        \nAll good  boss sound  calll super\n  \nGood quality.. 👍\n
#
#                                                     82  \
# Reviewer Name                                       Am
# Reviews        \nThe product was good in this price.\n
#
#                                                               83  \
# Reviewer Name                                         Ayush jeph
# Reviews        \nOverall good in all aspects. Thanks Amazon f...
#
#                           84                                   85  \
# Reviewer Name     Ayush jeph                                 Anil
# Reviews        \nGo for it\n  \nBahut sundar he aur acha bhi he\n
#
#                                         86            87  \
# Reviewer Name               Ramesh Salokhe   G. Santoshi
# Reviews        \nNice sound and durable.\n  \nDelicate\n
#
#                                             88  \
# Reviewer Name                            rohan
# Reviews        \nWorking really well for me.\n
#
#                                                               89
# Reviewer Name                                              rohan
# Reviews        \nThis earphone is good and perfect if you are...
#
# [2 rows x 90 columns]

# %% [markdown]
# ### **Transpose the dataframe.**

# %%
prod_reviews = df.T
print(prod_reviews.head(10))
# Out:
#         Reviewer Name                                            Reviews
# 0  Shokeenism Reviews  \nI brought this boat wireless headphones mult...
# 1     Amazon Customer  \nOverall an excellent product at this price. ...
# 2  Shokeenism Reviews  \nfull marks to sound quality.Dual connectivit...
# 3                  RK  \nGOOD PRODUCT BUT EVERYONE CANT BEAR TO USE I...
# 4       Brijesh Mehta  \nI'm writing this review after using the prod...
# 5               Rifuu  \noverall quality  is nice but bass quality is...
# 6              Promit  \nNeckband is of good quality. Gives a playbac...
# 7          Anil Patil  \nVery good headset at this price range.Connec...
# 8               Zaira         \nJust okokok  sound quality is not good\n
# 9       sandeep reddy                 \nGood Product value for money 👌\n

# %% [markdown]
# ### **Remove special characters from review text.**

# %%
prod_reviews['Reviews'] = prod_reviews['Reviews'].str.replace('\n','')
prod_reviews.head(5)
# Out:
#         Reviewer Name                                            Reviews
# 0  Shokeenism Reviews  I brought this boat wireless headphones multip...
# 1     Amazon Customer  Overall an excellent product at this price. Wh...
# 2  Shokeenism Reviews  full marks to sound quality.Dual connectivity ...
# 3                  RK  GOOD PRODUCT BUT EVERYONE CANT BEAR TO USE IN ...
# 4       Brijesh Mehta  I'm writing this review after using the produc...

# %% [markdown]
# ### **Convert Data Frame to a CSV File**

# %%
prod_reviews.to_csv('reviews.csv', index=False, header=True)
